# %% [markdown]
# # Question from Task 4 #
# ## Name: Bas Flikkema ##
# ## Username: bflikkema ##
# ## studentnumber: S5998662 ##
# ## Group: AS 4 ##

# %% [markdown]
# # Question 4.2 #

# %%
x = [1,2,3,10]
y = [10,20,30,40]
z = []
for i in range(len(y)):
    z.append(x[i] + y[i] )
print(z)
def myadd(a, b):
# Out:
# [11, 22, 33, 50]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       7 def myadd(a, b):
#       8     return a+b
# ----> 9 z = map(a,z)
#      10 print(z)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Question 4.3 #

# %%
from random import choice
D = [1,2,3,4,5,6]
dice = choice(D)
print(dice)
print(dice(10))
# The result is:'int' object is not callable
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       3 dice = choice(D)
#       4 print(dice)
# ----> 5 print(dice(10))
#
# TypeError: 'int' object is not callable

# %% [markdown]
# # Question 4.4 #

# %%
import pandas as pd
distances = [18.49, 35.48,  35.48, 11.34, 7.12,  9.82,  23.66, 44, 66.7,  52.4,  55, 25.6, 26.19]
velocities = [2094.75, 2320.87, 1224.9, 872.13, 432.2, 751, 1410, 2700, 5292, 2550, 5253, 2419, 2158]
x = sorted(distances)
v = sorted (velocities)
if len(x) ==  len(v):
    print( "Distances(Mpc)     Velocities")
    for i in range(len(x)):
        print(f"{x[i]}                {v[i]}")
# Out:
# Distances(Mpc)     Velocities
# 7.12                432.2
# 9.82                751
# 11.34                872.13
# 18.49                1224.9
# 23.66                1410
# 25.6                2094.75
# 26.19                2158
# 35.48                2320.87
# 35.48                2419
# 44                2550
# 52.4                2700
# 55                5253
# 66.7                5292
