# %%
x = 1000
y = 3.14
print(x/y)
# Out:
# 318.4713375796178

# %% [markdown]
# # Chapter 1
# ## Section
#
# *hello* **hello2**
#
# $$\sin(x) = \pi$$
#
# * item 1
# * item 2

# %%
print (x)
# Out:
# 1000
