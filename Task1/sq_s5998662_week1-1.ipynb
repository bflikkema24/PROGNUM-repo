# %% [markdown]
# Answers for week 1
# * Name: Bas Flikkema
# * Username: bflikkema
# * Student s-number: s5998662
# * Group: AS3

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# Question 1.3

# %%
x = 6
x *= 5
x *= 4
x *= 3
x *= 2
x *= 1

print (x)
# Out:
# 720

# %% [markdown]
# Question 1.4

# %%
import math
from scipy.constants import h
from scipy.constants import c
from scipy.constants import e
f =  2.42e28
E = h * f
E_ev = E/e
print (E_ev)
# Out:
# 100083158265557.38

# %% [markdown]
# Question 1.5

# %%
import math
from scipy.constants import G
mass_moon = 7.342e22
mass_earth = 5.9722e24
r = 385000600 
F = G*(mass_moon * mass_earth)/ r**2
print (F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# Question 1.7

# %%
x1 = 10
x2 = 22/7
print (x1, end ="")
print (x2, end ="")
# Out:
# 103.142857142857143

# %% [markdown]
# The code above places the numbers directly after one another.

# %% [markdown]
# Question 1.9

# %% [markdown]
# /bin/bash

# %% [markdown]
# A list of my files is given.

# %% [markdown]
# It also gives me dates of the files.

# %% [markdown]
# Using the command ls, and seeing if the a.txt file is shown.

# %% [markdown]
# It duplicates the a.txt file but names it b.txt.

# %% [markdown]
# The b.txt file is renamed to c.txt

# %% [markdown]
# The terminal tells me there is no such file or directory.

# %% [markdown]
# The terminal tells me there is no such file or directory.

# %% [markdown]
# By using the command ls again, if a.txt is not shown, the file is deleted.

# %% [markdown]
# Question 1.10

# %% [markdown]
# ![Filezilla screenshot.png](attachment:0568e9b6-7c8f-44fd-a66a-988c3d2790ba.png)

# %% [markdown]
# Question 1.12

# %% [markdown]
# ![Screenshot_20260211_162130-1.png](attachment:db1ae32e-bec5-41f1-9124-3bc6c9c4bff1.png)

# %% [markdown]
# Question 1.15

# %% [markdown]
# 1: /home/localuser3/Downloads

# %% [markdown]
# . refers to the current directory, so Downloads.
#
# .. refers to the parent directory, so localuser3.

# %% [markdown]
# Question 1.16

# %% [markdown]
# cd~/Desktop

# %% [markdown]
# Question 1.19

# %% [markdown]
# 1: All files are shown that contain a number between 0 and 9, and contain a letter c or o.
#
# 2: The brackets give a filter for the file. The characters you write in the brackets, have to be in the name of the file.
#
# 3: With this command, only files that end on co will be shown.
