# %% [markdown]
# # Embedded 2 #
# ## Name: Bas Flikkema ##
# ## Username: bflikkema ##
# ## Group: AS4 ##
# ## Student number: S5998662 ##
# --------

# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# # Question 2.1 #
# $$ E= \frac{hc}{\lambda} $$

# %% [markdown]
# # Question 2.2 #
# $$ F= G\frac{m_1m_2}{r^2} $$

# %% [markdown]
# # Question 2.3 #
# $$ \sin(2x)= 2\sin(x)\cos(x)=\frac{2\tan(x)}{1+\tan^2(x)} $$

# %% [markdown]
# <div class="alert alert-warning">
#   <b>Watch out!<b>
# <div>

# %% [markdown]
# The trigonometric terms like $\tan$ and $\sin$ should have a `\` in front. As you can see - it changes the font to be actual letters, instead of the font that signifies something similar to $s \cdot i \cdot n$

# %%
#Question 2.4
from math import *
alpha_d = 30                  # degrees
alpha_r = radians(alpha_d)    # Now in radians
x = sin(2*alpha_r)
print(x)
y = 2*sin(alpha_r)*cos(alpha_r)
print(y)
z = (2 * tan(alpha_r)) / (1 + tan(alpha_r)**2)
print(z)
# Out:
# 0.8660254037844386
# 0.8660254037844386
# 0.8660254037844386

# %% [markdown]
# ## Question 2.5 ##
# $$
#  \boxed{\sum_{k=0}^{\infty} \frac {1}{4k^2-1} = \frac {1}{2}}\
# $$
#
# $$
# \boxed{\int_0^\pi{e}^{ix}\,\mathrm{d}x = 2i} $$

# %% [markdown]
# <div class="alert alert-danger">
#   <b> Comments: <b>
# <div>

# %% [markdown]
# In this exercise we, unfortunately, explicitly want the formulas to be boxed, so please try to fix that

# %% [markdown]
# # Question 2.6 #
# ![image.png](attachment:8dd91139-a24f-4aaa-bcf4-b3be8e87f185.png)

# %% [markdown]
# # Question 2.7 #
# code \lambda
# # $$ \lambda $$ #

# %% [markdown]
# # Question 2.8 #
# ## $$ x = \sin(\lambda y)\tan(x^\frac{2}{3\pi}) $$ ##

# %%
from IPython.display import display, Math
from math import sin, pi

x = 9
Lambda = 0.5

s = rf"\sqrt({x}) = {x**0.5}\ and \sin(\lambda \pi)={sin(Lambda*pi)}"
print(s)
m = Math(s)
display(m)
# Out:
# \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0
# $\displaystyle \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0$

# %% [markdown]
# # Question 2.9 #

# %%
from math import exp, log 
x = 6
a = exp(log(x))

print(a)
# Out:
# 6.0

# %% [markdown]
# $$ e^{log(x)}=x $$

# %% [markdown]
# # Question 2.10 #

# %%
from math import factorial
x = factorial(100)
print(x)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %% [markdown]
# ## There is no real limit to the integer numbers, as a number of over 100 factorial is basically infinity ##

# %% [markdown]
# # Question 2.11 #

# %%
x = eval(input())
type(x)
print(type (x))
# the difference between 24//7 and 24//7.0 is that the latter will show class 'float' and 24/7 will show class 'int'.
# Out:
#  24//7.0
# <class 'float'>

# %% [markdown]
# <div class="alert alert-warning">
#   <b>Watch out!<b>
# <div>

# %% [markdown]
# What about the second part of the exercise, regarding the difference between inputting `24//7` and `24//7.0`?

# %% [markdown]
# # Question 2.13 #

# %%
from math import * 
x = 2
y = 3
#1
atan2(y, x)
print(atan2(y, x))
#2
z = tan(atan2(y, x))
print(z)
print("1.5 corresponds to 3 over 2, which is y over x.")
# Out:
# 0.982793723247329
# 1.5
# 1.5 corresponds to 3 over 2, which is y over x.

# %% [markdown]
# # Question 2.16 #
# Compiler: The compiler translates code into another language before executing said code.
# Interpreter: An interpreter is a program that can execute instructions written in a high-level programming language.
# Python binding: a Python binding is compiled code written in C, C++ or Fortran.

# %% [markdown]
# # Question 2.17 #
# #!/usr/bin/env python

# %% [markdown]
# # Question 2.18 #
# - chmod u+x abc.py
# - mv abc.py abc
# - python abc
# - abc
# - [bflikkema@hydra29 bin]$ python abc
# - a1
# - b2
# - c1
# - x=-1.0
# - [bflikkema@hydra29 bin]$ abc
# - a2
# - b4
# - c1
# - x1=-0.2928932188134524 x2=-1.7071067811865475

# %% [markdown]
# # Question 2.19 #

# %%
import math
X = range(-10, 10)
Y = []
for x in X:
    y = math.exp(-(x/5)**2)
    Y.append(round(y,3))
b = slice (2,18,2)
print(Y[b])
a = slice (0,18,2)
print(X[a])
sum(Y[b])
# Out:
# [0.077, 0.237, 0.527, 0.852, 1.0, 0.852, 0.527, 0.237]
# range(-10, 8, 2)
# 4.309

# %% [markdown]
# <div class="alert alert-warning">
#   <b>Watch out!<b>
# <div>

# %% [markdown]
# Unfortunately your slice syntax is incorrect, because you use the last even index still. One piece of advice - if you make the slice correctly, then you only need to use `Y[b]` and `X[b]`, and your `b` slice object is very close to the desired one - think about how to excluse the last even index

# %% [markdown]
# # Question 2.20 #

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
intersection = set(night1) & set(night2)
print(intersection)
if 5  in night1 and 5 in night2:
    print(f"{5} is an intersection of night1 and night2")
else:
    print(f"{5} is not an intersection of night1 and night2")

if 5  in night1:
    print(f"{5} is part of night1")
else:
    print(f"{5} is not part of night1")
# Out:
# {0, 1, 2, 3, 4}
# 5 is not an intersection of night1 and night2
# 5 is part of night1

# %% [markdown]
# # Question 2.23 #

# %%
a = b = [1,2,3,4]
c = b
a[2]=0
# a[2] = [0,1,2,3]
#This code will put the list after the equal sign, at the third index of the list given for a.
print(c)
# This causes the lists of b and c to present a value 'False' in the place of a[2]==0, as the second value of a, is not 0.
# Out:
# [1, 2, 0, 4]

# %% [markdown]
# <div class="alert alert-warning">
#   <b>Watch out!<b>
# <div>

# %% [markdown]
# Ang what about the other part of the exercise reharding how to fix this issue? Copying lists in python is possible, question is how

# %% [markdown]
# # Question 2.24 #

# %%
import numpy as np
random_numbers = np.random.normal(0, 1.4, 100000)
print(random_numbers)
standard_deviation = np.std(random_numbers)
print(standard_deviation)
# Out:
# [-0.70146928  0.41277966 -1.66694235 ...  0.41167914 -0.11547308
#  -1.1684098 ]
# 1.3960578468090872

# %% [markdown]
# <div class="alert alert-danger">
#   <b> Comments: <b>
# <div>

# %% [markdown]
# First steps are correct, but you didn't calculate the standard deviation of this set

# %% [markdown]
# # Question 2.26 #

# %% [markdown]
# ## I have sent my image to someone and they were able to open it. ##

# %% [markdown]
# # Question 2.27 #

# %% [markdown]
# - anaconda/2020.07
# - anaconda/2022.10
# - anaconda/2023.03

# %% [markdown]
# # Question 2.28 #

# %% [markdown]
# # ![image.png](attachment:0cb274a9-e453-4885-9d0e-e304fc477abe.png)![image.png](attachment:a7f6fb40-64b1-4c0b-b6f0-cf7fdc135377.png) #

# %% [markdown]
# <div class="alert alert-info">
#   <b>Overall Feedback<b>
# <div>

# %% [markdown]
# Despite a couple of inconsistencies, this is a much better embedded notebook than last time! There are a couple of things to fix, but from what I see it is the precision which could use some work, as your programming itself seems very nice! Please watch out for the homeworks though, because similarly to here - your programming is good, but you do not stick to what the exercises state
