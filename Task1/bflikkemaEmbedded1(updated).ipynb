# %% [markdown]
# Answers for Week 1: The local computing environment
#
# * Name: Bas Flikkema
# * Username: bflikkema
# * Student number: S5998662
# * Group: AS4

# %%
x = 22/7

# %% [markdown]
# $$y = \frac{sin(x)}{x}$$

# %% [markdown]
# pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# # 1. When does my Kapteyn account expire? #
# ## September ##
# # 2. Where is the list with tasks for which I have to write a report? #
# ## Under weekly tasks ##
# # 3. What is the email address of the lecturer? #
# ## vogelaar@astro.rug.nl ##
# # 4. What kind of information can I find in my personal grading record? #
# ## Information about my personal scores for homeworks, midterms and presency for example. ##
# # 5. To which group am I assigned according to the personal grading record? #
# ## 4 ##
# # 6. Who is my T.A. and what is his/her mail address? #
# ## T.A.: Bartosz   mail address: bstrent@astro.rug.nl ##
# # 7. When are the scheduled sessions for my group? #
# ## Monday 15-18, Wednesday 11-14 and Thursday 14-17 ##

# %% [markdown]
# # Question 1.4 augmented assignement operators #

# %%
x = 6
print (x)
# Out:
# 6

# %%
x *= 5
print (x)
# Out:
# 30

# %%
x *= 4
print (x)
# Out:
# 120

# %%
x *= 3
print (x)
# Out:
# 360

# %%
x *= 2
print (x)
# Out:
# 720

# %%
x *= 1
print (x)
# Out:
# 720

# %% [markdown]
# # Question 1.5 Energy of a single photon #

# %%
f = 2.42 * 10**28
from scipy.constants import h
print (h)
E= h*f
print (E)
# Out:
# 6.62607015e-34
# 1.6035089762999996e-05

# %% [markdown]
# # Question 1.6 Gravitational pull #

# %%
from scipy.constants import G
M1 = 5.9722*10**24
M2 = 7.342*10**22
r = 385000.6*10**3
F = G*(M1 * M2) /r**2
print (F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# # Question 1.7 Kepler's third law (HOMEWORK) #

# %%
from scipy.constants import G
from scipy.constants import pi
a = 1.475 * 10**11
p = 31556926
m= (4 * pi**2 * a**3)/ (p**2 * G)
print (m)
# Out:
# 1.9060780983450785e+30

# %% [markdown]
# # Question 1.8 #
# # 1 #
# ## /bin/bash shows on the command line ##
# # 2 #
# ## A list is shown of , Desktops Documents Downloads Music Picturers Public Task1.ipynb Templates untitled.ipynb Videos ##
# # 3 #
# ## the same list is shown but now ordered vertically and presented with a time ##
# # 4 #
# ## This can be checked by seeing if a new document has popped up in Jupyter ##
# # 5 #
# ## the file a.txt is copied and this new file is given b.txt ##
# # 6 #
# ## the file b.txt is renamed to c.txt ##
# # 7 #
# ## a map is created by the name PROGNUM ##
# # 8 #
# ## You go into the PROGNUM folder
# # 9 #
# ## - ##
# # 10 #
# ## It creates the file a.txt in the folder Task1 ##
# # 11 #
# ## You go into the users directory and after ls, it shows Users in the same way as for subquestion 2 ##
# # 12 #
# ## You can go back to the folder and see if the file has disappeared. ##

# %% [markdown]
# # Question 1.9 #
# ![image.png](attachment:dfb2f81f-33aa-4120-a3eb-c033d04509d7.png)![image.png](attachment:28d01315-8b85-4a03-b000-f2cd4752de9c.png)

# %% [markdown]
# # Question 1.10 #
# ![image.png](attachment:ff6e15c4-c7ff-432d-8b8c-0eaad8fdddf4.png)![image.png](attachment:4e39c69b-7019-4d23-be6b-581d30a98c9f.png)

# %% [markdown]
# # Question 1.11 #
# ![image.png](attachment:aa183127-b0bc-4230-984b-7aa4250054f1.png)![image.png](attachment:5403f692-a964-49b5-ab2f-1312279b1df4.png)

# %% [markdown]
# # Question 1.12 #
# ## It stands for American Standard Code for Information Interchange ##
# ## A tool with which you can edit an ASCII file is kate ##

# %% [markdown]
# # Question 1.13 #
# ## 1. URL means Uniform Resource Locator ##
# ## 2. No, it does not ##

# %% [markdown]
# # Question 1.14 #
# ## Using forward, you create a .forward file in your home directory. Then you put your mail address in this file and then mail that is received, is forwarded to the given mail addresses by the Kapteyn mail server. ##

# %% [markdown]
# # Question 1.15 #
# ## Phishing is contacting someone (by mail) in the hope that the receiver opens the provided link. The sender has malware installed that can be used to find your password or username. It is important to verify the sender of the mail and until then, not open any URL's. Furthermore, the spelling or grammar can also give away that you have received a phishing mail and not a regular one. ##

# %% [markdown]
# # Question 1.17 #

# %% [markdown]
# # Question 1.18 #
# ## 1.  the system command line shows /Users/users/bflikkema ##
# ## 2. to the Users directory ##

# %% [markdown]
# # Question 1.19 #
# ## cd Desktop ##

# %% [markdown]
# # Question 1.21 #
# ## the command line shows that the file is an ASCII-file ##

# %% [markdown]
# # Question 1.22 #
# ## 1. The command shows me file t1.c ##
# ## 2. The brackets identify a class that a file must contain, so in this case, it must contain a number from 0 to 9. ##
# ## 3. It shows me the files t3.co and t7b3.co ##

# %% [markdown]
# <div class="alert alert-danger">
#   <b> Comments: <b>
# <div>

# %% [markdown]
# Incorrect. Since I cannot see your files and folder structure, I cannot give much feedback. Try to take a look again yourself - but feel free to message me on my email to figure this out - Please fix this

# %% [markdown]
# # Question 1.23 #
# ## 1. pressing the TAB-key adds the .c to my file name ##
# ## 2. my previous command is copied, when is type ls first, the last ls command is copied ##

# %% [markdown]
# # Question 1.25 #
# ![image.png](attachment:954f2649-556c-43ad-a779-250aebb79abd.png)![image.png](attachment:0129cf93-a1fd-4cb2-98d5-5ac8d6611eec.png)

# %% [markdown]
# ## 2. the bulk disc should be used for big data sets ##
# ## 4. I can now type the command, ls virgo01, and this shows myverybigdataset ##

# %% [markdown]
# <div class="alert alert-danger">
#   <b> Comments: <b>
# <div>

# %% [markdown]
# The symbolic link was not created correctly. Remove it using the `rm` command and try to create it again. To see if you made it correctly, type `ls -l` in the terminal. It should display the current path of the symlink - Please fix this

# %% [markdown]
# # Question 1.26 #
# ## 1. the numbers mean how much data is used ##
# ## 2. it displays the data in human friendly units, like MB or GB ##

# %% [markdown]
# # Question 1.27 #
# ## Virgo01 currently uses the most data, equal to myverybigdataset. They use 512.0 B each ##

# %% [markdown]
# # Question 1.28 #
# ## 1. Read, Write and eXecute ##
# ## 2. it is readable for all the users, as per default. By this I mean there is no protection by standard, so anyone can read it, within Kapteyn.##
# ## 3. you type chmod filename -r, to make the file only readable for others. ##
# ## 4. You can ##
# ## 5. The command .bashrc tells me command not found, so no. ##
# ## 6. No, you can not. ##

# %% [markdown]
# <div class="alert alert-danger">
#   <b> Comments: <b>
# <div>

# %% [markdown]
# Answer to subquestion 2 is not precise enough - state its protections for all: user, group and owner. In subquestion 3 - state the exact command you would use. Subquestions 4, 5, 6 not attempted at all, so no feedback available - attempt them first - Please fix this

# %% [markdown]
# # Question 1.29 #

# %% [markdown]
# # Question 1.30 #
# ## I applied the grep command, but I could  not find the string task ##

# %% [markdown]
# # Question 1.31 #
# ## this is what the command is supposed to do ##

# %% [markdown]
# # Question 1.32 #
# ## A bunch of lines of code show up in the terminal containing my username marked in red ##

# %% [markdown]
# # Question 1.33 #
# ## It appears to be not possible, due to the firewall ##

# %% [markdown]
# # Question 1.35 #
# ## This should be it. ##
# ![image.png](attachment:3527e867-60cb-46a0-841f-2b57def75184.png)![image.png](attachment:c065b5dc-66be-4cb0-b054-628dbc38152e.png)

# %% [markdown]
# <div class="alert alert-danger">
#   <b> Comments: <b>
# <div>

# %% [markdown]
# Incorrect. Since I cannot see your files and folder structure, I cannot give much feedback. Try to take a look again yourself - but feel free to message me on my email to figure this out - Please fix this

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %% [markdown]
# <div class="alert alert-info">
#   <b>Overall Feedback<b>
# <div>

# %% [markdown]
# Overall, there is room for improvement and a number of milestone questions has to be resubmitted, though the questions that are correct are done nicely. For each question, see feedback above. Please resubmit a corrected version as soon as you can
