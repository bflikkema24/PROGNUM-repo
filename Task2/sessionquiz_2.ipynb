# %% [markdown]
# Latex basics
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# Question 2.1
# $$ E = hc/\lambda $$

# %% [markdown]
# Question 2.2
# $$ F = G\frac{m_1m_2}{r^2} $$

# %% [markdown]
# Question 2.3
# $$ \sin(2x) = 2\sin(x)\cos(x) = \frac{2\tan(x)}{1 + \tan^2 (x)} $$

# %% [markdown]
# Question 2.4

# %%
from math import *
h = pi/2
a = sin(2 * h)
print (a)
b = 2 * sin(h) * cos(h)
print (b)
c =  2 * tan(h) / (1 + tan(h)**2)
print (c)
# Out:
# 1.2246467991473532e-16
# 1.2246467991473532e-16
# 1.2246467991473532e-16

# %% [markdown]
# Question 2.5
# $$ \sum_{k=0}^{\infty} \frac{1}{4k^2 -1} = \frac{1}{2} $$
# $$ \int_{0}^{\pi} e^{ix} dx = 2i $$

# %% [markdown]
# Question 2.6
# $$ \lambda $$

# %%
from IPython.display import display, Math
from math import sin, pi

x = 9
Lambda = 0.5

s = rf"\sqrt({x}) = {x**0.5}\ and \sin(\lambda \pi)={sin(Lambda*pi)}"
print(s)
m = Math(s)
display(m)
# Out:
# \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0
# $\displaystyle \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0$

# %% [markdown]
# Question 2.8

# %%
import math
a = 3
l = exp(log(a))
 
print(a)
print(l)
# Out:
# 3
# 3.0000000000000004

# %% [markdown]
# Question 2.9

# %%
from math import *
a = factorial(100)
print(a)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %% [markdown]
# This answer tells me that the number of integers Python can return, is quite massive.

# %% [markdown]
# Question 2.11

# %%
import math
x = (3/2)
y = math.atan(x)
print (y)
f = tan(y)
print(f)
# Out:
# 0.982793723247329
# 1.5

# %% [markdown]
# Question 2.12

# %%
 from math import atan2, degrees
x = float(input(f" Your x-coordinate is"))
y = float(input(f" Your y-coordinate is"))
a = math.atan2(y, x)
b = degrees(a)
print (b)
if b > 0 and b < 90:
    print(f" This point is in the first quadrant.")
elif b > 90 and b < 180:
    print (f" This point is in the second quadrant.")
elif b > -90 and b < 0:
    print (f" This point is in the fourth quadrant.")
elif b > -180 and b < -90:
    print (f" This point is in the third quadrant.")
# Out:
#  Your x-coordinate is -1
#  Your y-coordinate is 2
# 116.56505117707799
#  This point is in the second quadrant.

# %% [markdown]
# Question 2.14

# %%
X = [1.36, 1.46, 1.41, 2.12, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18] 
print(X)
X.append(0.51)
X.remove(2.12)
print (X)
X_slice = slice(2, 8 ,2 )
x = X[X_slice]
print (x)
Sum = sum(x)
print(Sum)
# Out:
# [1.36, 1.46, 1.41, 2.12, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18]
# [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# [1.41, 0.98, 1.97]
# 4.359999999999999

# %% [markdown]
# The value at index 6 is 1.97.
#
# The index of 1.46 is 1.

# %% [markdown]
# Question 2.15

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
a = set(night1)
b = set(night2)
c = a.intersection(b)
print (c)
d = 5 in c
print(f"Is 5 in the intersection list? {d}")
e = 5 in a
print(f"Is 5 in list a? {e}")
# Out:
# {0, 1, 2, 3, 4}
# Is 5 in the intersection list? False
# Is 5 in list a? True

# %% [markdown]
# Question 2.18

# %%
a = b = [1,2,3,4]
c = b
a[2] = 0
print(a)
# Out:
# [1, 2, 0, 4]

# %% [markdown]
# Question 2.19

# %%
import numpy as np
a = np.random.normal(0,1.4,100000)
std = np.std(a)
print(std)
# Out:
# 1.4017335265260875

# %% [markdown]
# Question 2.21

# %%
x = [1,2]
for i in range (0,99):
    f = x[-1] + x[-2]
    x.append(f)
print(f"The 100th term of the Fibonacci sequence is {x[99]}")
# Out:
# The 100th term of the Fibonacci sequence is 573147844013817084101

# %% [markdown]
# ![Screenshot from 2026-02-20 10-13-54.png](attachment:34da7527-15a2-454d-8cdd-05dfd5203af0.png)

# %% [markdown]
# Question 2.22

# %%
import math
from math import sin

import math as ma
from ma import sin
